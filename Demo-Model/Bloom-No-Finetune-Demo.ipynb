# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install -q scipy
# !pip install -U accelerate
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.31.0.dev0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.23.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-7b1")
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-7b1")

# Define the input prompt
input_text = "Hello"

# Tokenize the input
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate the output using the model
output = model.generate(input_ids, max_length=50)

# Decode the generated output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Hello, my name is Michael.
# I'm a writer.
# I live in New York.
# I have a wife and a daughter.
# I have a dog.
# I have a cat.
# I have a job.
# I have a house.
# I have a car.

# %%
input_text = "Dịch sư tử sang tiếng nga"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=100)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Dịch sư tử sang tiếng nga là gì? Dịch vụ dịch thuật tiếng nga tại Hà Nội, dịch thuật tiếng nga tại HCM, dịch thuật tiếng nga tại Đà Nẵng, dịch thuật tiếng nga tại Hải Phòng, dịch thuật tiếng nga tại Cần Thơ, dịch thuật tiếng nga tại Biên Hòa, dịch thuật tiếng nga tại Vũng Tàu, dịch thuật tiếng nga tại Đồng Nai, dịch thuật tiếng nga tại Bình Dương, dịch thuật tiếng nga tại Long An, dịch thuật tiếng nga tại Tiền Giang, dịch thuật tiếng nga tại Bến Tre,

# %%
input_text = "Đề xuất 1 cuốn sách hay"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Đề xuất 1 cuốn sách hay, 1 bài viết hay, 1 video hay, 1 bài chia sẻ hay, 1 bài học hay, 1 bài giảng hay, 1 bài chia sẻ kinh nghiệm hay, 1 bài chia sẻ kiến thức hay, 1 bài chia sẻ kỹ năng hay, 1 bài chia sẻ kinh nghiệm sống hay, 1 bài chia sẻ kỹ năng sống hay, 1 bài chia sẻ kinh nghiệm làm việc hay, 1 bài chia sẻ kiến thức làm việc hay, 1 bài chia sẻ kỹ năng làm việc hay, 1 bài chia sẻ kinh nghiệm học tập hay, 1 bài chia sẻ kiến thức học tập hay, 1 bài chia sẻ kỹ năng học tập hay, 1 bài chia sẻ kinh nghiệm làm việc hay, 1 bài chia sẻ kiến thức làm việc hay, 1 bài chia sẻ kỹ năng làm việc hay, 1 bài chia sẻ kinh nghiệm học tập hay, 1 bài chia sẻ kiến thức học tập hay, 1 bài chia sẻ kỹ năng học tập hay, 1 bài chia sẻ kinh nghiệm sống hay, 1 bài chia

# %%
input_text = "Ăn gì để khỏe mạnh?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Ăn gì để khỏe mạnh? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì để tăng cường sức đề kháng? Ăn gì để tăng cường hệ miễn dịch? Ăn gì

# %%
input_text = "Có nên làm việc online không?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Có nên làm việc online không? Làm việc online có tốt không? Làm việc online có kiếm được tiền không? Làm việc online có bị lừa không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị đánh giá không? Làm việc online có bị

# %%
input_text = "Viết 1 câu chia buồn với người bạn thân"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
#
"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Thế vận hội Olympic diễn ra bao nhiêu năm một lần? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì? Olympic là gì?

# %%
input_text = "Cúp bóng đá thế giới gần nhất được tổ chức ở đâu?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Cúp bóng đá thế giới gần nhất được tổ chức ở đâu? | Bóng đá Quốc tế | Thanh Niên
# Cúp bóng đá thế giới gần nhất được tổ chức ở đâu? | Bóng đá Quốc tế | Thanh Niên
# Cúp bóng đá thế giới (World Cup) là giải đấu bóng đá lớn nhất hành tinh, được tổ chức 4 năm một lần. Giải đấu này được tổ chức lần đầu tiên vào năm 1930 tại Uruguay. Sau đó, giải đấu được tổ chức tại nhiều quốc gia khác nhau, nhưng không có quốc gia nào tổ chức giải đấu này nhiều lần như Brazil.

# %%
input_text = "Ai là tổng thống hiện tại của Hoa Kỳ?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Ai là tổng thống hiện tại của Hoa Kỳ?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa Kỳ hiện tại?”, “Ai là tổng thống Hoa

# %%
input_text = "Viết một hàm Python in ra Hello, World!"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Viết một hàm Python in ra Hello, World! trong một file .py. Hàm này sẽ được gọi từ một file .py khác.

# %%
input_text = "Làm thế nào để cộng hai số trong Python? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để cộng hai số trong Python?  Làm thế nào để cộng hai số trong Python?

# %%
input_text = "HTML là viết tắt của gì?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# HTML là viết tắt của gì? HTML là viết tắt của HyperText Markup Language, là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một ngôn ngữ lập trình được sử dụng để tạo ra các trang web. HTML là một

# %%
input_text = "Hãy hướng dẫn cách làm một chiếc bánh mì kẹp"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Hãy hướng dẫn cách làm một chiếc bánh mì kẹp thịt bò thơm ngon, hấp dẫn cho cả nhà thưởng thức nhé!
# Bước 1: Thịt bò rửa sạch, thái lát mỏng. Ướp thịt bò với 1 thìa cà phê hạt nêm, 1 thìa cà phê đường, 1 thìa cà phê nước mắm, 1 thìa cà phê dầu ăn, 1 thìa cà phê tỏi băm, 1 thìa cà phê tiêu xay, 1 thìa cà phê hành tím băm, 1 thìa cà phê bột ngọt, 1 thìa cà phê bột bắp, 1 thìa cà phê bột chiên giòn, 1 thìa cà phê dầu ăn, 1 thìa cà phê hành lá băm, 1 thìa cà phê tỏi băm, 1 thìa cà phê tiêu xay, 1 thìa cà phê dầu ăn, 1 thìa cà phê hành lá băm, 1 thìa cà phê tỏi băm, 1 thìa cà phê tiêu xay, 1 thìa cà phê dầu ăn, 1 thìa cà phê hành

# %%
input_text = "Làm thế nào để làm bài tập về nhà? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để làm bài tập về nhà? 。[nhạc sống hà tây remix]Đây là trang web được chỉ định duy nhất cung cấp các dịch vụ thông tin chuyên nghiệp.
# Kế tiếp：Cục Thống kê: Giá trị gia tăng của các ngành trên quy mô chỉ định tăng 8,0% trong tháng 4 | Sản xuất | Giá trị gia tăng công nghiệ
# đồng hồ casio nữ giá rẻ nhạc sống hà tây remix hay nhất nhạc sống hà tây remix hay nhất nhạc sống hà tây remix hay nhất nhạc sống hà tây remix hay nhất nhạc sống hà tây remix hay nhất
# đồng hồ casio nữ giá rẻ是凤凰财经Kênh tin tức Sands Kết hợp nhiều năm kinh nghiệm chuyên môn，Sử dụng hệ thống giám sát thông tin tiên tiến nhất để theo dõi chặt chẽ các tin tức liên quan, sau đó trải qua quá trình sàng lọc chuyên nghiệp và nghiêm ngặt, cuối cùng là tích hợp
# nước hoa charme nữTân Hoa Xã, Bắc Kinh, ngày 9 tháng 11 (Phóng viên Zhang Qiang)

# %%
input_text = "Làm thế nào để gửi một email?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email? Làm thế nào để gửi một email?

# %%
input_text = "Hãy hướng dẫn cách gấp một con hạc giấy."

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Hãy hướng dẫn cách gấp một con hạc giấy. Bạn có thể gấp một con hạc giấy theo nhiều cách khác nhau. Bạn có thể gấp một con hạc giấy theo hình tròn, hình vuông, hình tam giác, hình chữ nhật, hình elip, hình tròn có cánh, hình tròn không cánh, hình chữ nhật có cánh, hình chữ nhật không cánh, hình elip có cánh, hình elip không cánh, hình tròn có cánh có đuôi, hình tròn không cánh có đuôi, hình chữ nhật có cánh có đuôi, hình chữ nhật không cánh có đuôi, hình elip có cánh có đuôi, hình elip không cánh có đuôi, hình tròn có cánh có đuôi có mỏ, hình tròn không cánh có đuôi có mỏ, hình chữ nhật có cánh có đuôi có mỏ, hình chữ nhật không cánh có đuôi có mỏ, hình elip có cánh có đuôi có mỏ, hình elip không cánh có đuôi có mỏ, hình tròn có cánh có đuôi có mỏ có đuôi, hình tròn không cánh có đuôi có mỏ có đuôi, hình chữ nhật có cánh có đuôi có mỏ có đuôi, hình chữ nhật không cánh có đuôi có mỏ có đuôi, hình elip có cánh có đuôi có mỏ có đuôi, hình elip không cánh có đuôi có mỏ có đuôi, hình tròn có cánh có đuôi có mỏ có đuôi có mỏ, hình tròn không cánh có đuôi có mỏ có đuôi có mỏ, hình chữ nhật có cánh có đuôi có mỏ có đuôi có mỏ, hình chữ nhật không cánh có đuôi có mỏ

# %%
input_text = "Làm sao để khỏe mạnh?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm sao để khỏe mạnh? Làm sao để sống lâu? Làm sao để sống vui? Làm sao để sống hạnh phúc? Làm sao để sống có ích? Làm sao để sống có giá trị? Làm sao để sống có ý nghĩa? Làm sao để sống có đạo đức? Làm sao để sống có nhân cách? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao để sống có ích cho xã hội? Làm sao để sống có ích cho gia đình? Làm sao để sống có ích cho bản thân? Làm sao để sống có ích cho người khác? Làm sao
