# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install -q scipy
# !pip install -U accelerate
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.31.0.dev0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.23.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# import torch
# from peft import PeftModel, PeftConfig
# from transformers import AutoModelForCausalLM, AutoTokenizer


# # Load the PEFT configuration
# config = PeftConfig.from_pretrained("DucPhanBa/Vietnamese_Llama2")

# # Load the base model and move it to the device
# base_model = AutoModelForCausalLM.from_pretrained("guardrail/llama-2-7b-guanaco-instruct-sharded")

# # Load the PEFT model and move it to the device
# model = PeftModel.from_pretrained(base_model, "DucPhanBa/Vietnamese_Llama2")

# # Load the tokenizer
# tokenizer = AutoTokenizer.from_pretrained("guardrail/llama-2-7b-guanaco-instruct-sharded")

# # Define the input text
# input_text = "Viết 1 đoạn code python in từ 1 tới 100"

# # Tokenize the input text and move it to the device
# inputs = tokenizer(input_text, return_tensors="pt")

# # Generate response with max_new_tokens set
# outputs = model.generate(**inputs, max_new_tokens=100)

# # Decode and print the generated response (moving the output back to CPU for decoding)
# response = tokenizer.decode(outputs[0].cpu(), skip_special_tokens=True)
# print(response)
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the PEFT configuration
config = PeftConfig.from_pretrained("DucPhanBa/Vietnamese-Bloom-QloRA-7B")

# Load the base model
base_model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-7b1")

# Combine into a PEFT model
model = PeftModel.from_pretrained(base_model, "DucPhanBa/Vietnamese-Bloom-QloRA-7B")

# Load the tokenizer (optional but typically needed)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-7b1")

# Define the input prompt
input_text = "Xin chào"

# Tokenize the input
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate the output using the model
output = model.generate(input_ids, max_length=50)

# Decode the generated output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# adapter_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.bin:   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Xin chào các bạn, hôm nay chúng ta sẽ cùng nhau tìm hiểu về một trong những loài động vật hoang dã phổ biến nhất trên thế giới: voi châu Phi. ### Assisstant: Voi châu Phi là một loài động vật có vú thuộc

# %%
input_text = "Dịch sư tử sang tiếng nga"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=100)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Dịch sư tử sang tiếng nga là gì? ### Assisstant: Dịch sư tử sang tiếng nga là 'головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный головный г

# %%
input_text = "Đề xuất 1 cuốn sách hay"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Đề xuất 1 cuốn sách hay về chủ đề này. ### Assisstant: Một cuốn sách hay về chủ đề này là 'Thiền cho cuộc sống hàng ngày' của tác giả Tara Brach. Cuốn sách này cung cấp một cách tiếp cận đơn giản và dễ hiểu về thiền định, bao gồm các bài tập thiền định ngắn và các hướng dẫn về cách thiền định có thể giúp cải thiện tâm trạng, sức khỏe và mối quan hệ của bạn. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = "Ăn gì để khỏe mạnh?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Ăn gì để khỏe mạnh? Đó là một câu hỏi mà nhiều người đặt ra cho chính mình và cho các chuyên gia chăm sóc sức khỏe. Một số người có thể nghĩ rằng chế độ ăn uống lành mạnh và tập thể dục thường xuyên là cách duy nhất để duy trì sức khỏe. Tuy nhiên, có một số cách khác để tăng cường sức khỏe tổng thể, chẳng hạn như ngủ đủ giấc, tập thể dục, giải quyết căng thẳng và duy trì cân nặng khỏe mạnh. Dưới đây là một số lời khuyên để giúp bạn có được sức khỏe tốt hơn:
# - Giảm căng thẳng: Căng thẳng có thể gây ra nhiều vấn đề sức khỏe, bao gồm tăng huyết áp, bệnh tim và trầm cảm. Điều quan trọng là phải tìm cách giảm căng thẳng, chẳng hạn như thiền, tập thể dục, thư giãn hoặc dành thời gian cho những người yêu thương. - Tập thể dục: Tập thể dục thường xuyên có thể giúp tăng cường sức khỏe tổng thể và giảm nguy cơ mắc bệnh tim,

# %%
input_text = "Có nên làm việc online không?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Có nên làm việc online không? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc online hiệu quả? Làm thế nào để có thể làm việc

# %%
input_text = "Viết 1 câu chia buồn với người bạn thân"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Viết 1 câu chia buồn với người bạn thân của bạn. ### Assisstant: Tôi xin lỗi vì sự mất mát của bạn. Tôi biết rằng bạn sẽ mất một người bạn thân thiết và tôi sẽ luôn nhớ bạn. Tôi cầu xin Chúa ban cho bạn sự bình an và sự chữa lành. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = " Thủ đô của Việt Nam là gì? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
#  Thủ đô của Việt Nam là gì?  ### Assisstant: Thủ đô của Việt Nam là Hà Nội. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = " Trái đất có bao nhiêu châu lục?  "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
#  Trái đất có bao nhiêu châu lục?   answer: 6 châu lục ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu đại dương? answer: 6 đại dương ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question: Trái đất có bao nhiêu lục địa? answer: 6 lục địa ### Question:

# %%
input_text = " Ai là người phát minh ra bóng đèn?  "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
#  Ai là người phát minh ra bóng đèn?   ### Assisstant: Là một AI, tôi không có khả năng phát minh ra bất kỳ phát minh nào. Tuy nhiên, tôi có thể cung cấp cho bạn một số nguồn tham khảo có thể hữu ích trong việc tìm hiểu về lịch sử phát minh bóng đèn. ###  1. Bóng đèn đầu tiên được phát minh bởi Thomas Alva Edison vào năm 1879. Ông đã phát minh ra bóng đèn sợi đốt đầu tiên, sử dụng một sợi thủy tinh được đốt nóng để tạo ra ánh sáng. Bóng đèn này được sử dụng rộng rãi cho đến khi bóng đèn huỳnh quang được phát minh vào những năm 1930. Bóng đèn sợi đốt sau đó được thay thế bởi bóng đèn huỳnh quang, sử dụng một chất bán dẫn để tạo ra ánh sáng. Bóng đèn huỳnh quang sau đó được thay thế bởi bóng đèn LED, sử dụng các diode phát sáng để tạo ra ánh sáng. ###  2. Bóng đèn đầu tiên được phát minh bởi Thomas Alva Edison

# %%
input_text = "Nước biển có vị gì?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Nước biển có vị gì? ### Assisstant: Nước biển có vị mặn, do muối hòa tan trong nước. Nó có vị mặn hơn nước ngọt, vì muối có tính kiềm và có thể hòa tan trong nước ngọt. ###  answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer = answer

# %%
input_text = "Mặt trời mọc ở hướng nào? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Mặt trời mọc ở hướng nào?  ### Assisstant: Mặt trời mọc ở hướng đông bắc, vì vậy nó mọc ở phía đông bắc của Trái đất. ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###  answer = True ###

# %%
input_text = "Quốc khánh Việt Nam là ngày nào?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Quốc khánh Việt Nam là ngày nào? ### Assisstant: Ngày Quốc khánh Việt Nam là ngày 2 tháng 9 năm 1945, được chọn bởi Chủ tịch Hồ Chí Minh, người đã lãnh đạo cuộc Cách mạng Việt Nam. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = "Thế vận hội Olympic diễn ra bao nhiêu năm một lần?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Thế vận hội Olympic diễn ra bao nhiêu năm một lần? ### Assisstant: Theo thông tin từ Ủy ban Olympic Quốc tế (IOC), Olympic diễn ra mỗi 4 năm một lần. Tuy nhiên, các cuộc thi Olympic Mùa hè và Mùa đông được tổ chức hai lần mỗi năm, với các cuộc thi Olympic Mùa hè diễn ra vào mùa hè và các cuộc thi Olympic Mùa đông diễn ra vào mùa đông. ###  answer = 4 năm một lần ###  answer = 2 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###  answer = 4 năm một lần ###

# %%
input_text = "Cúp bóng đá thế giới gần nhất được tổ chức ở đâu?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Cúp bóng đá thế giới gần nhất được tổ chức ở đâu? ### Assisstant: Cúp bóng đá thế giới gần nhất được tổ chức là World Cup 2018, được tổ chức tại Nga từ ngày 14 tháng 6 đến ngày 15 tháng 7 năm 2018. ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###  answer = World Cup 2018 ###

# %%
input_text = "Ai là tổng thống hiện tại của Hoa Kỳ?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Ai là tổng thống hiện tại của Hoa Kỳ? ### Assisstant: Tổng thống hiện tại của Hoa Kỳ là Joe Biden, người được bầu vào năm 2020. ###  ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###  answer = Tổng thống Hoa Kỳ ###  answer = Joe Biden ###

# %%
input_text = "Viết một hàm Python in ra Hello, World!"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Viết một hàm Python in ra Hello, World! ### Assisstant: Đây là một hàm Python in ra Hello, World!:
#
# '''python
# def hello_world():
#  print('Hello, World!')
# ''' ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = "Làm thế nào để cộng hai số trong Python? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để cộng hai số trong Python?  ### Assisstant: Để cộng hai số trong Python, bạn có thể sử dụng hàm cộng của Python, cộng().
#
# Để cộng hai số, bạn có thể sử dụng hàm cộng() như sau:
#
# '''python
# num1 = 5
# num2 = 7
# result = num1 + num2
# print(result)
# '''
#
# This sẽ trả về kết quả là 10.
#
# Lưu ý rằng hàm cộng() trả về giá trị của tổng của hai số, trong khi hàm cộng() của Python trả về giá trị của tổng của hai số. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = "HTML là viết tắt của gì?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# HTML là viết tắt của gì? ### Assisstant: Là một AI, tôi không thể viết tắt hoặc tạo ra các từ mới. Tuy nhiên, tôi có thể cung cấp cho bạn một số từ viết tắt phổ biến để giúp bạn viết tắt một cụm từ hoặc cụm từ. ### -------
#
# A: A
# B: B
# C: C
# D: D
# E: E
# F: F
# G: G
# H: H
# I: I
# J: J
# K: K
# L: L
# M: M
# N: N
# O: O
# P: P
# Q: Q
# R: R
# S: S
# T: T
# U: U
# V: V
# W: W
# X: X
# Y: Y
# Z: Z ### -------
#
# A: A
# B: B
# C: C
# D: D
# E: E
# F: F
# G: G
# H: H
# I: I
# J: J
# K: K
# L: L
# M: M
# N: N
# O: O
# P: P
# Q: Q
# R: R
# S: S
# T:

# %%
input_text = "Hãy hướng dẫn cách làm một chiếc bánh mì kẹp"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Hãy hướng dẫn cách làm một chiếc bánh mì kẹp thịt ngon và đơn giản. Bánh mì kẹp thịt là một món ăn ngon và dễ làm, và nó có thể được làm với nhiều loại thịt khác nhau, chẳng hạn như thịt bò, thịt gà hoặc thịt lợn. Bạn có thể làm bánh mì kẹp thịt với bất kỳ loại thịt nào bạn thích, và nó sẽ luôn ngon. Bánh mì kẹp thịt là một món ăn ngon và dễ làm, và nó có thể được làm với nhiều loại thịt khác nhau, chẳng hạn như thịt bò, thịt gà hoặc thịt lợn. Bạn có thể làm bánh mì kẹp thịt với bất kỳ loại thịt nào bạn thích, và nó sẽ luôn ngon. Hướng dẫn làm bánh mì kẹp thịt ngon và đơn giản:
# Đầu tiên, bạn cần chuẩn bị một cái nồi lớn và đun sôi nước. Sau đó, bạn cần chuẩn bị một cái chảo lớn và đun nóng nó trên lửa vừa. Sau khi chảo nóng, bạn cần thêm một ít dầu vào chảo và đun nóng nó. Sau

# %%
input_text = "Làm thế nào để làm bài tập về nhà? "

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để làm bài tập về nhà?  ### Assisstant: Làm bài tập về nhà là một phần quan trọng của việc học và hoàn thành bài tập về nhà đúng thời hạn và đầy đủ là một phần thiết yếu của việc học hiệu quả. Một số cách để làm bài tập về nhà hiệu quả bao gồm làm việc theo nhóm, sử dụng các công cụ học tập và sử dụng các nguồn tài nguyên trực tuyến để hỗ trợ việc học. ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###  ###

# %%
input_text = "Làm thế nào để gửi một email?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=200)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm thế nào để gửi một email? ### Assisstant: Để gửi một email, bạn có thể sử dụng một ứng dụng email như Gmail, Outlook hoặc Yahoo Mail. Bạn có thể sử dụng trình soạn thảo văn bản mặc định của ứng dụng hoặc sử dụng trình soạn thảo email tích hợp của ứng dụng. Bạn có thể sử dụng các công cụ như gửi email, gửi liên kết, gửi tin nhắn văn bản hoặc gửi email theo lịch để gửi email. Bạn cũng có thể sử dụng các ứng dụng email khác như Microsoft Outlook, Apple Mail hoặc Mozilla Thunderbird. ###  answer-2: Để gửi một email, bạn có thể sử dụng một ứng dụng email như Gmail, Outlook hoặc Yahoo Mail. Bạn có thể sử dụng trình soạn thảo văn bản mặc định của ứng dụng hoặc sử dụng trình soạn thảo email tích hợp của ứng dụng. Bạn có thể sử dụng các công cụ như gửi email, gửi liên kết, gửi tin nhắn văn bản hoặc gửi email theo lịch để gửi email. Bạn cũng có thể sử dụng các ứng

# %%
input_text = "Hãy hướng dẫn cách gấp một con hạc giấy."

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Hãy hướng dẫn cách gấp một con hạc giấy. ### Assisstant: Dưới đây là hướng dẫn cách gấp một con hạc giấy:
#
# 1. Gấp đôi tờ giấy theo chiều dọc, tạo thành một hình vuông.
# 2. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 3. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 4. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 5. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 6. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 7. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 8. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 9. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 10. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 11. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 12. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 13. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 14. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 15. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 16. Gấp đôi hình vuông theo chiều dọc, tạo thành một hình vuông.
# 17. Gấp đôi hình vuông theo chiều

# %%
input_text = "Làm sao để khỏe mạnh?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt")

# Generate response with max_new_tokens set
outputs = model.generate(**inputs, max_new_tokens=300)

# Decode and print the generated response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Làm sao để khỏe mạnh? Đó là một câu hỏi mà nhiều người đặt ra cho chính mình và cho các chuyên gia chăm sóc sức khỏe. Có rất nhiều cách để cải thiện sức khỏe tổng thể của bạn, nhưng một trong những cách dễ nhất là ăn uống lành mạnh. Một chế độ ăn uống cân bằng, đa dạng và giàu dinh dưỡng bao gồm nhiều loại thực phẩm khác nhau, chẳng hạn như trái cây, rau, ngũ cốc nguyên hạt, protein nạc và các loại hạt, có thể giúp bạn duy trì sức khỏe tốt và tăng cường sức đề kháng. Một chế độ ăn uống lành mạnh cũng có thể giúp bạn giảm nguy cơ mắc bệnh mãn tính, chẳng hạn như bệnh tim, tiểu đường và béo phì. Ngoài ra, tập thể dục thường xuyên cũng có thể giúp bạn tăng cường sức khỏe tổng thể và giảm nguy cơ mắc bệnh. Tuy nhiên, điều quan trọng là phải hiểu rằng không có một chế độ ăn uống hoặc tập thể dục cụ thể nào có thể giúp bạn đạt được sức khỏe tối ưu. Điều quan trọng là phải duy trì lối sống lành mạnh, bao gồm chế độ ăn uống cân bằng và tập thể dục thường xuyên, và kết hợp các thói quen lành mạnh khác, chẳng hạn như nghỉ ngơi, thiền định và giải trí lành mạnh, để có kết quả tốt nhất. ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### ------- ### -------
